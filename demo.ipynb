# %% [markdown]
# # RAPTOR: Recursive Abstractive Processing for Tree-Organized Retrieval

# %%
# NOTE: An OpenAI API key must be set here for application initialization, even if not in use.
# If you're not utilizing OpenAI models, assign a placeholder string (e.g., "not_used").
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
# Cinderella story defined in sample.txt
with open('demo/facultymanual.txt', 'r') as file:
    text = file.read()

print(text[:100])
# Out:
#
#
# Title:
# FACULTY  MANUAL  Reference No.  OPR – HRD – D – M – 003
# DEPARTMENT  HUMAN RESOURCES

# %% [markdown]
# 1) **Building**: RAPTOR recursively embeds, clusters, and summarizes chunks of text to construct a tree with varying levels of summarization from the bottom up. You can create a tree from the text in 'sample.txt' using `RA.add_documents(text)`.
#
# 2) **Querying**: At inference time, the RAPTOR model retrieves information from this tree, integrating data across lengthy documents at different abstraction levels. You can perform queries on the tree with `RA.answer_question`.

# %% [markdown]
# ### Building the tree

# %%
from raptor import RetrievalAugmentation
# Out:
# 2024-04-01 16:17:32,451 - Loading faiss.
# 2024-04-01 16:17:32,561 - Successfully loaded faiss.

# %%
RA = RetrievalAugmentation()

# construct the tree
RA.add_documents(text)
# Out:
# 2024-04-01 16:18:08,109 - Successfully initialized TreeBuilder with Config
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 100
#             Num Layers: 5
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 100
#             Summarization Model: <raptor.SummarizationModels.GPT3TurboSummarizationModel object at 0x32206f490>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x32206f350>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
# 2024-04-01 16:18:08,110 - Successfully initialized ClusterTreeBuilder with Config
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 100
#             Num Layers: 5
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 100
#             Summarization Model: <raptor.SummarizationModels.GPT3TurboSummarizationModel object at 0x32206f490>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x32206f350>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
# 2024-04-01 16:18:08,111 - Successfully initialized RetrievalAugmentation with Config
#         RetrievalAugmentationConfig:
#
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 100
#             Num Layers: 5
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 100
#             Summarization Model: <raptor.SummarizationModels.GPT3TurboSummarizationModel object at 0x32206f490>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x32206f350>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
#
#
#         TreeRetrieverConfig:
#             Tokenizer: None
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x322097cd0>
#             Num Layers: None
#             Start Layer: None
#
#
#             QA Model: <raptor.QAModels.GPT3TurboQAModel object at 0x3203ed9d0>
#             Tree Builder Type: cluster
#
# 2024-04-01 16:18:08,111 - Splitting Text
# 2024-04-01 16:18:08,181 - Creating Leaf Nodes
# 2024-04-01 16:18:10,121 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,122 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,123 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,123 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,124 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,417 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,429 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,433 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,439 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,445 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,451 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,561 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,622 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,639 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,645 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,686 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,710 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,728 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,735 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,748 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,766 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,771 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,779 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,795 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,880 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,967 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,973 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:10,998 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,034 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,047 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,060 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,062 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,063 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,115 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,132 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,147 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,155 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,232 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,232 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,259 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,331 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,341 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,341 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,378 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,379 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,399 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,451 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,456 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,463 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,538 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,544 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,545 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,548 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,622 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,667 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,689 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,694 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,709 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,737 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,747 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,763 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,783 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,807 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,864 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,879 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,912 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,921 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:11,949 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,019 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,021 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,029 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,041 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,086 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,098 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,119 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,156 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,176 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,189 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,217 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,229 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,264 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,328 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,334 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,365 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,372 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,425 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,432 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,440 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,532 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,536 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,548 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,557 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,605 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,642 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,691 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,717 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,737 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,750 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,805 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,836 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,849 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,870 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,872 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,889 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,913 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,914 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:12,995 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,004 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,038 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,052 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,063 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,129 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,142 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,161 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,186 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,189 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,197 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,203 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,216 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,295 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,312 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,346 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,364 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,435 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,450 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,465 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,488 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,492 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,512 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,526 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,547 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,625 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,636 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,640 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,671 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,688 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,707 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,777 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,777 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,790 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,799 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,807 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,813 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,818 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,884 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,946 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,952 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,959 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,986 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:13,998 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,006 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,089 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,099 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,099 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,101 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,106 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,142 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,149 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,171 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,275 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,280 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,290 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,293 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,350 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,401 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,413 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,413 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,418 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,418 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,428 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,438 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,453 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,564 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,580 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,594 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,594 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,630 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,635 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,681 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,694 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,698 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,716 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,723 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,724 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,751 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,756 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,880 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,902 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,916 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,934 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,955 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,959 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,965 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:14,984 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:15,008 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:15,010 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:15,012 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:15,055 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:15,068 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:15,160 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:15,205 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:15,236 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:18:15
- HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 RA = RetrievalAugmentation()
#       3 # construct the tree
# ----> 4 RA.add_documents(text)
#
# File ~/Documents/GitHub/raptor/raptor/RetrievalAugmentation.py:217, in RetrievalAugmentation.add_documents(self, docs)
#     213     if user_input.lower() == "y":
#     214         # self.add_to_existing(docs)
#     215         return
# --> 217 self.tree = self.tree_builder.build_from_text(text=docs)
#     218 self.retriever = TreeRetriever(self.tree_retriever_config, self.tree)
#
# File ~/Documents/GitHub/raptor/raptor/tree_builder.py:264, in TreeBuilder.build_from_text(self, text, use_multithreading)
#     261 logging.info("Creating Leaf Nodes")
#     263 if use_multithreading:
# --> 264     leaf_nodes = self.multithreaded_create_leaf_nodes(chunks)
#     265 else:
#     266     leaf_nodes = {}
#
# File ~/Documents/GitHub/raptor/raptor/tree_builder.py:242, in TreeBuilder.multithreaded_create_leaf_nodes(self, chunks)
#     236 future_nodes = {
#     237     executor.submit(self.create_node, index, text): (index, text)
#     238     for index, text in enumerate(chunks)
#     239 }
#     241 leaf_nodes = {}
# --> 242 for future in as_completed(future_nodes):
#     243     index, node = future.result()
#     244     leaf_nodes[index] = node
#
# File ~/miniconda3/envs/RAPTOR/lib/python3.11/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     238     if wait_timeout < 0:
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#     246     finished = waiter.finished_futures
#
# File ~/miniconda3/envs/RAPTOR/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File ~/miniconda3/envs/RAPTOR/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Querying from the tree
#
# ```python
# question = # any question
# RA.answer_question(question)
# ```

# %%
question = "What is considered official business?"

answer = RA.answer_question(question=question)

print("Answer: ", answer)
# Out:
# 2024-03-29 13:59:46,905 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-03-29 13:59:49,006 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Answer:  Official Business at National University is defined as work conducted outside the institution to represent the school at various events like conferences, seminars, trainings, and meetings. This can also include representing the university at CHED meetings. Additionally, official business includes all travels by messengers, liaisons, and other personnel tasked to coordinate with other offices in relation to the needs of National University, such as local government units, SM offices, banks, and other campuses. Any transaction or travel is considered official business when duly reported to the National University.

# %%
# Save the tree by calling RA.save("path/to/save")
SAVE_PATH = "demo/faculty"
RA.save(SAVE_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Save the tree by calling RA.save("path/to/save")
#       2 SAVE_PATH = "demo/faculty"
# ----> 3 RA.save(SAVE_PATH)
#
# NameError: name 'RA' is not defined

# %%
# load back the tree by passing it into RetrievalAugmentation

RA = RetrievalAugmentation(tree=SAVE_PATH)

question = "How can an employee resign?"

answer = RA.answer_question(question=question)
print("Answer: ", answer)
# Out:
# 2024-04-01 16:19:30,631 - Successfully initialized TreeBuilder with Config
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 100
#             Num Layers: 5
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 100
#             Summarization Model: <raptor.SummarizationModels.GPT3TurboSummarizationModel object at 0x32206f490>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x32206f350>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
# 2024-04-01 16:19:30,631 - Successfully initialized ClusterTreeBuilder with Config
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 100
#             Num Layers: 5
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 100
#             Summarization Model: <raptor.SummarizationModels.GPT3TurboSummarizationModel object at 0x32206f490>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x32206f350>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
# 2024-04-01 16:19:30,631 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: None
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x322097cd0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-04-01 16:19:30,632 - Successfully initialized RetrievalAugmentation with Config
#         RetrievalAugmentationConfig:
#
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 100
#             Num Layers: 5
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 100
#             Summarization Model: <raptor.SummarizationModels.GPT3TurboSummarizationModel object at 0x32206f490>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x32206f350>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
#
#
#         TreeRetrieverConfig:
#             Tokenizer: None
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x322097cd0>
#             Num Layers: None
#             Start Layer: None
#
#
#             QA Model: <raptor.QAModels.GPT3TurboQAModel object at 0x3203ed9d0>
#             Tree Builder Type: cluster
#
# 2024-04-01 16:19:32,827 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-04-01 16:19:36,652 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Answer:  To resign from National University as an employee, the following steps must be followed:
#
# 1. Write a formal resignation letter addressed to the Dean of the university.
# 2. The Dean must acknowledge the receipt of the resignation letter and signify acceptance of the resignation.
# 3. A copy of the signed resignation letter should be forwarded to the HR department within twenty-four hours from receipt and acceptance to initiate the processing of clearance.
# 4. Management reserves the right to require the resigning employee to render a 30-day notice before the resignation takes effect.
#
# It is important to follow these procedures to ensure a smooth and proper resignation process from National University.

# %% [markdown]
# ## Using other Open Source Models for Summarization/QA/Embeddings
#
# If you want to use other models such as Llama or Mistral, you can very easily define your own models and use them with RAPTOR.

# %%
import torch
from raptor import BaseSummarizationModel, BaseQAModel, BaseEmbeddingModel, RetrievalAugmentationConfig
from transformers import AutoTokenizer, pipeline

# %%
# if you want to use the Gemma, you will need to authenticate with HuggingFace, Skip this step, if you have the model already downloaded
from huggingface_hub import login
login()

# %%
from transformers import AutoTokenizer, pipeline
import torch

# You can define your own Summarization model by extending the base Summarization Class. 
class GEMMASummarizationModel(BaseSummarizationModel):
    def __init__(self, model_name="google/gemma-2b-it"):
        # Initialize the tokenizer and the pipeline for the GEMMA model
        # access_token = "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"
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.summarization_pipeline = pipeline(
            "text-generation",
            model=model_name,
            #model_kwargs={"torch_dtype": torch.bfloat16},
            device="mps"
            # device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),  # Use "cpu" if CUDA is not available
        )

    def summarize(self, context, max_tokens=150):
        # Format the prompt for summarization
        messages=[
            {"role": "user", "content": f"Write a summary of the following, including as many key details as possible: {context}:"}
        ]
        
        prompt = self.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
        
        # Generate the summary using the pipeline
        outputs = self.summarization_pipeline(
            prompt,
            max_new_tokens=max_tokens,
            do_sample=True,
            temperature=0.7,
            top_k=50,
            top_p=0.95
        )
        
        # Extracting and returning the generated summary
        summary = outputs[0]["generated_text"].strip()
        return summary

# %%
class GEMMAQAModel(BaseQAModel):
    def __init__(self, model_name= "google/gemma-2b-it"):
        # Initialize the tokenizer and the pipeline for the model
        # access_token = "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"
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.qa_pipeline = pipeline(
            "text-generation",
            model=model_name,
            #model_kwargs={"torch_dtype": torch.bfloat16},
            device="mps"
            # device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
        )

    def answer_question(self, context, question):
        # Apply the chat template for the context and question
        messages=[
              {"role": "user", "content": f"Given Context: {context} Give the best full answer amongst the option to question {question}"}
        ]
        prompt = self.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
        
        # Generate the answer using the pipeline
        outputs = self.qa_pipeline(
            prompt,
            max_new_tokens=256,
            do_sample=True,
            temperature=0.7,
            top_k=50,
            top_p=0.95
        )
        
        # Extracting and returning the generated answer
        answer = outputs[0]["generated_text"][len(prompt):]
        return answer

# %%
from sentence_transformers import SentenceTransformer
class SBertEmbeddingModel(BaseEmbeddingModel):
    def __init__(self, model_name="sentence-transformers/multi-qa-mpnet-base-cos-v1"):
        self.model = SentenceTransformer(model_name)

    def create_embedding(self, text):
        return self.model.encode(text)

# %%
device = torch.device('mps')
print(device)

# %%
RAC = RetrievalAugmentationConfig(summarization_model=GEMMASummarizationModel(), qa_model=GEMMAQAModel(), embedding_model=SBertEmbeddingModel())

# %%
RA = RetrievalAugmentation(config=RAC)

# %%
with open('demo/sample.txt', 'r') as file:
    text = file.read()
    
RA.add_documents(text)

# %%
question = "How did Cinderella reach her happy ending?"

answer = RA.answer_question(question=question)

print("Answer: ", answer)
